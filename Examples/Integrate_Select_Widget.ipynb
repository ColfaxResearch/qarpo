# %% [markdown]
# ### Integrate text widget
# Qarpo is a library to build a jupyter notebook user interface to submit jobs to job scheduler, display output interface to display accomplished jobs' outputs and plot its results.
#
# This notebook provides a recipe to integrate select widget to input interface
#
# To start using the qarpo, run the following import line

# %%
import qarpo

# %% [markdown]
# This notebook provides a recipe to build an input user interface.
# Input user interface is a tool that allows notebook users to configure and build the command that will be submitted to the cluster.
#
# To integrate select input to the UI configuration, a new entry ("inputs") is added to the configuration dictionary.
#
#     "inputs": # Define the inputs shows in the Jupyter notebook for job configuration
#         [
#             {
#                 "Target_node": # Unique ID of the input
#                               {
#                                   "display_name": <string>,  # Displayed input name
#                                   "type": "select",          # Input type (text/select)
#                                   "default" : <string>,      # Default input value
#                                   "defines" : <list of strings, defines where the input value will be placed in the command>     # (controls what the input defines),
#                                   "options": #options info
#                                              [
#                                                   {   #This entry is the first default entry in the select list
#                                                       "name": "Select Node",
#                                                       "dummy": "True"
#                                                   },
#                                                   {    #the select list options starts from the 2nd entry
#                                                        "name": <display name of the option>,
#                                                        "defines" : #controls what value to insert in the command line
#                                                                    {
#                                                                        <string, what to replace in command> : <the value that will be placed in the command line>
#                                                                     }
#                                                     },
#                                               ]
#                                }
#                 }
#         ]

# %%
job_interface = qarpo.Interface( {
                        "job": # Define how to launch the job and interpret results
                                {
                                    "command": "qsub app/example_job.sh -l nodes=1:NODE -F 'RESULTS'",
                                    "output_type": ".png",         # The type of input (text/video)
                                    "results_path": "app/results/", # Path to job result files
                                    "results_defines" : "RESULTS",
                                    "progress_indicators":          # List of job progress indicators
                                    [
                                        { 
                                            "file_name": "i_progress.txt", # File with progress info
                                            "title": "Progress"            # Display name in the notebook
                                        }
                                    ],
                                    "plots":[
                                        {
                                            "title" : "",
                                            "type" : "time",
                                            "xlabel" : "",
                                            "ylabel" : "",
                                            "selector" : ["Target node"]
                                        }
                                    ]
                                },
                        "inputs": # Define the inputs shows in the Jupyter notebook for job configuration
                                [
                                    {
                                        "Target_node": # Unique ID of the input
                                            { 
                                                "display_name": "Target node",   # Displayed input name
                                                "type": "select",                  # Input type (text/select)
                                                "default" : "tank-870", # Default input value
                                                "defines" : ["NODE"],
                                                "options": [
                                                    {
                                                        "name": "Select Node", 
                                                        "dummy": "True"

                                                    },
                                                    
                                                    {
                                                        "name": "IEI/tank-870/SKL", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc001skl"
                                                                }
                                                    },
                                                    {
                                                        "name": "IEI/tank-870/SKL/HDDLR", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc002mx8"
                                                                }
                                                    },
                                                    {
                                                        "name": "IEI/tank-870/SKL/FPGA", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc003a10"
                                                                }
                                                    },
                                                    {
                                                        "name": "IEI/tank-870/SKL/NCS2", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc004nc2"
                                                                }
                                                    },
                                                    {
                                                        "name": "IEI/tank-870/KBL", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc006kbl"
                                                                }
                                                    },
                                                    {
                                                        "name": "IEI/tank-870/SKL/XEON", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc007xv5"
                                                                }
                                                    },
                                                    {
                                                        "name": "UP-Squared", 
                                                        "defines" :
                                                                {
                                                                   "NODE" : "idc008u2g"
                                                                }
                                                    },
                    
                                                    {
                                                        "name": "JWIP/KBL", 
                                                        "defines":    
                                                            {
                                                                "NODE" : "idc009jkl"
                                                            }
                                                    },
                                                    {
                                                        "name": "JWIP/ATOM", 
                                                        "defines":    
                                                            {
                                                                "NODE" : "idc010jal"
                                                            }
                                                    }
                                                ]
                                        }
                                        }
                                    ]
                                })

# %%
job_interface.displayUI()
